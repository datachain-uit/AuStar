# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df_final = pd.read_csv(r'C:\mydata\G8Vitamin\data\duy\raw_final.csv')

# %%
# Check information dataset
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30065 entries, 0 to 30064
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SEQN                      30065 non-null  float64
#  1   Gender                    30065 non-null  float64
#  2   Age                       30065 non-null  float64
#  3   Race                      30065 non-null  float64
#  4   PIR                       27524 non-null  float64
#  5   Weight                    29603 non-null  float64
#  6   Height                    29635 non-null  float64
#  7   BMI                       29511 non-null  float64
#  8   WaistCircumference        28600 non-null  float64
#  9   Hba1c                     28397 non-null  float64
#  10  FastingGlucose            28302 non-null  float64
#  11  Albumin                   27953 non-null  float64
#  12  ALT                       27923 non-null  float64
#  13  AST                       27912 non-null  float64
#  14  AlkalinePhosphotase       27948 non-null  float64
#  15  BUN                       27949 non-null  float64
#  16  GGT                       27947 non-null  float64
#  17  TotalBilirubin            27937 non-null  float64
#  18  UricAcid                  27946 non-null  float64
#  19  Creatinine                27950 non-null  float64
#  20  TotalCholesterol          28030 non-null  float64
#  21  HDLCholesterol            28030 non-null  float64
#  22  Triglycerides             27761 non-null  float64
#  23  LDLCholesterol            27040 non-null  float64
#  24  Hemoglobin                28430 non-null  float64
#  25  Hematocrit                28430 non-null  float64
#  26  MeanCellVolumn            28430 non-null  float64
#  27  MeanCellHemoglobin        28437 non-null  float64
#  28  RedCellDistributionWidth  28430 non-null  float64
#  29  PlateletCount             28429 non-null  float64
#  30  MeanPlateletVolume        28429 non-null  float64
#  31  milk_consumption          30064 non-null  float64
#  32  VitaminD                  27722 non-null  float64
#  33  YearID                    30065 non-null  object
# dtypes: float64(33), object(1)
# memory usage: 7.8+ MB

# %%
threshold = 1e-10

# Select numeric columns
numeric_cols = df_final.select_dtypes(include='number').columns

# Apply threshold replacement only on numeric columns
df_final[numeric_cols] = df_final[numeric_cols].applymap(
    lambda x: 0 if abs(x) < threshold else x
)
# Out:
# C:\Users\iseT1enLoc\AppData\Local\Temp\ipykernel_31452\1268272764.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_final[numeric_cols] = df_final[numeric_cols].applymap(

# %%
# === Step 1: Extract string to get first year in cycle "2001-2002" 
df_final['YearStart'] = df_final['YearID'].str[:4].astype(int)
df_final = df_final.drop(columns=['YearID'])

#  === Step 2: Create label from VitaminD ===
def binary_vitamin_d_label(row):
    val = row['VitaminD']
    year = row['YearStart']

    if pd.isna(val) or pd.isna(year):
        return None  

    return 1 if val < 50 else 0

df_final['label'] = df_final.apply(binary_vitamin_d_label, axis=1)

# === Step 3: Get data from 2013 previous ===
df_final_train = df_final[df_final['YearStart'] <= 2013]
df_final_test = df_final[df_final['YearStart'] > 2013]

# === Step 4: Write to CSV file ===
df_final_train.to_csv(r'C:\mydata\G8Vitamin\data\duy\train.csv', index=False)
df_final_test.to_csv(r'C:\mydata\G8Vitamin\data\duy\test.csv', index=False)

# === Log information line number ===
print(f"✅ Số dòng train: {len(df_final_train)} được lưu vào train.csv")
print(f"✅ Số dòng test : {len(df_final_test)} được lưu vào test.csv")
# Out:
# ✅ Số dòng train: 23838 được lưu vào train.csv
# ✅ Số dòng test : 6227 được lưu vào test.csv
