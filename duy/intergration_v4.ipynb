# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
DATA_DIRECTORY = r"C:\mydata\G8Vitamin\data\processed"
print(DATA_DIRECTORY)
# Out:
# C:\mydata\G8Vitamin\data\processed

# %% [markdown]
# # 2001-2002

# %%
selected_columns_B = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",                           
    "RIAGENDR","RIDAGEYR", "RIDRETH1",      # DEMO_B: Sex, Age, Skin Color
    "BMXBMI",                               # BMX_B: BMI
    "LBXGLU",                               # L10AM_B: FastingGlucose mg/dl
    "LBXGH",                                # L10_B: Glycohemoglobin %
    "LBXSATSI",                             # L40_B: ALT U/L
    "LBXSASSI",                             # L40_B: AST U/L
    "LBXSGTSI",                             # L40_B: GGT U/L
    "LBDSAPSI",                             # L40_B: Alkaline Phosphatase U/L
    "LBDSTB",                               # L40_B: Total Bilirubin mg/dl
    "LBXSAL",                               # L40_B: Albumin g/dl
    "LBDSCR",                               # L40_B: Creatinine mg/dl
    "LBXSBU",                               # L40_B: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # L40_B: Uric Acid mg/dl
    "LBDTCSI",                              # L13_B:Total Cholesterol mmol/l
    "LBDHDLSI",                             # L13_B: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # L13AM_B: LDL Cholesterol mmol/l
    "LBDTRSI",                              # L13AM_B: Triglycerides mmol/l
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # L25_B: Blood Count
    "INDFMPIR",                             # DEMO_B: PIR 
    "DBD196",                               # DBQ_B
    "LBDVIDMS",                             # VID_B: Vitamin D
]
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2001-2002", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2001-2002", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2001-2002", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2001-2002", "Questionnaire")

DEMO_B     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_B.csv"))       
BMX_B      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_B.csv"))       
L10_B      = pd.read_csv(os.path.join(LAB_PATH, "L10_B.csv"))         
L10_AM_B   = pd.read_csv(os.path.join(LAB_PATH, "L10AM_B.csv"))     
L40_B     = pd.read_csv(os.path.join(LAB_PATH, "L40_B.csv"))        
L13_B     = pd.read_csv(os.path.join(LAB_PATH, "L13_B.csv"))         
L13_AM_B  = pd.read_csv(os.path.join(LAB_PATH, "L13AM_B.csv")) 
L25_B     = pd.read_csv(os.path.join(LAB_PATH, "L25_B.csv"))      
DBQ_B     = pd.read_csv(os.path.join(QUESTION_PATH,'DBQ_B.csv'))     
VID_2_B    = pd.read_csv(os.path.join(LAB_PATH, "VID_B.csv"))


DEMO_B   = DEMO_B.loc[:, DEMO_B.columns.isin(selected_columns_B)]
BMX_B    = BMX_B.loc[:, BMX_B.columns.isin(selected_columns_B)]
L10_B    = L10_B.loc[:, L10_B.columns.isin(selected_columns_B)]
L10_AM_B = L10_AM_B.loc[:, L10_AM_B.columns.isin(selected_columns_B)]
L40_B    = L40_B.loc[:, L40_B.columns.isin(selected_columns_B)]
L13_B    = L13_B.loc[:, L13_B.columns.isin(selected_columns_B)]
L13_AM_B = L13_AM_B.loc[:, L13_AM_B.columns.isin(selected_columns_B)]
L25_B    = L25_B.loc[:, L25_B.columns.isin(selected_columns_B)]
DBQ_B    = DBQ_B.loc[:, DBQ_B.columns.isin(selected_columns_B)]
VID_2_B  = VID_2_B.loc[:, VID_2_B.columns.isin(selected_columns_B)]

# Start with DEMO_B
merged_df_B = DEMO_B

# Merge one by one on SEQN
merged_df_B = pd.merge(merged_df_B, BMX_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B = pd.merge(merged_df_B, L10_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B = pd.merge(merged_df_B, L10_AM_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B = pd.merge(merged_df_B, L40_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B = pd.merge(merged_df_B, L13_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B = pd.merge(merged_df_B, L13_AM_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B = pd.merge(merged_df_B, L25_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B = pd.merge(merged_df_B, DBQ_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B = pd.merge(merged_df_B, VID_2_B, on="SEQN", how="inner", validate="one_to_one")
merged_df_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3666 entries, 0 to 3665
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3666 non-null   float64
#  1   RIAGENDR  3666 non-null   float64
#  2   RIDAGEYR  3666 non-null   float64
#  3   RIDRETH1  3666 non-null   float64
#  4   INDFMPIR  3409 non-null   float64
#  5   BMXWT     3547 non-null   float64
#  6   BMXHT     3577 non-null   float64
#  7   BMXBMI    3493 non-null   float64
#  8   BMXWAIST  3515 non-null   float64
#  9   LBXGH     3457 non-null   float64
#  10  LBXGLU    3441 non-null   float64
#  11  LBXSAL    3392 non-null   float64
#  12  LBXSATSI  3392 non-null   float64
#  13  LBXSASSI  3392 non-null   float64
#  14  LBDSAPSI  3392 non-null   float64
#  15  LBXSBU    3392 non-null   float64
#  16  LBXSGTSI  3392 non-null   float64
#  17  LBDSTB    3391 non-null   float64
#  18  LBXSUA    3392 non-null   float64
# ...

# %% [markdown]
# # 2003-2004

# %%
selected_columns_C = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",
    "RIAGENDR", "RIDAGEYR", "RIDRETH1",     # DEMO_C: Sex, Age, Skin Color
    "BMXBMI",                               # BMX_C
    "LBXGLU",                               # L10AM_C - FastingGlucose (mg/dL)
    "LBXGH",                                # L10_C - Glycohemoglobin (%)
    "LBXSATSI",                             # L40_C: ALT U/L
    "LBXSASSI",                             # L40_C: AST U/L
    "LBXSGTSI",                             # L40_C: GGT U/L
    "LBXSAPSI",                             # L40_C: Alkaline Phosphatase U/L
    "LBXSTB",                               # L40_C: Total Bilirubin mg/dl
    "LBXSAL",                               # L40_C: Albumin g/dl
    "LBXSCR",                               # L40_C: Creatinine mg/dl
    "LBXSBU",                               # L40_C: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # L40_C: Uric Acid mg/dl
    "LBDTCSI",                              # L13_C: Total Cholesterol mmol/l
    "LBDHDDSI",                             # L13_C: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # L13AM_C: LDL Cholesterol mmol/l
    "LBDTRSI",                              # L13AM_C: Triglycerides mmol/l    
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # L25_C: Blood Count
    "INDFMPIR",                            # DEMO_C: PIR
    "DBD197",                              # DBQ_C: Milk
    "LBDVIDMS",                            # VID_C: Vitamin D
]
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2003-2004", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2003-2004", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2003-2004", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2003-2004", "Questionnaire")

DEMO_C     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_C.csv"))
BMX_C      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_C.csv"))
L10_C      = pd.read_csv(os.path.join(LAB_PATH, "L10_C.csv"))
L10_AM_C   = pd.read_csv(os.path.join(LAB_PATH, "L10AM_C.csv"))
L40_C     = pd.read_csv(os.path.join(LAB_PATH, "L40_C.csv"))
L13_C     = pd.read_csv(os.path.join(LAB_PATH, "L13_C.csv"))
L13_AM_C  = pd.read_csv(os.path.join(LAB_PATH, "L13AM_C.csv"))
L25_C     = pd.read_csv(os.path.join(LAB_PATH, "L25_C.csv"))
L06VID_C   = pd.read_csv(os.path.join(LAB_PATH, "VID_C.csv"))
DBQ_C = pd.read_csv(os.path.join(QUESTION_PATH,'DBQ_C.csv'))


DEMO_C     = DEMO_C.loc[:, DEMO_C.columns.isin(selected_columns_C)]
BMX_C      = BMX_C.loc[:, BMX_C.columns.isin(selected_columns_C)]
L10_C      = L10_C.loc[:, L10_C.columns.isin(selected_columns_C)]
L10_AM_C   = L10_AM_C.loc[:, L10_AM_C.columns.isin(selected_columns_C)]
L40_C     = L40_C.loc[:, L40_C.columns.isin(selected_columns_C)]
L13_C     = L13_C.loc[:, L13_C.columns.isin(selected_columns_C)]
L13_AM_C  = L13_AM_C.loc[:, L13_AM_C.columns.isin(selected_columns_C)]
L25_C =  L25_C.loc[:, L25_C.columns.isin(selected_columns_C)]
DBQ_C = DBQ_C.loc[:, DBQ_C.columns.isin(selected_columns_C)]
L06VID_C   = L06VID_C.loc[:, L06VID_C.columns.isin(selected_columns_C)]

merged_df_C = DEMO_C
merged_df_C = pd.merge(merged_df_C, BMX_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C = pd.merge(merged_df_C, L10_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C = pd.merge(merged_df_C, L10_AM_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C = pd.merge(merged_df_C, L40_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C = pd.merge(merged_df_C, L13_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C = pd.merge(merged_df_C, L13_AM_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C = pd.merge(merged_df_C, L25_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C = pd.merge(merged_df_C, DBQ_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C = pd.merge(merged_df_C, L06VID_C, on="SEQN", how="inner", validate="one_to_one")
merged_df_C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3356 entries, 0 to 3355
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3356 non-null   float64
#  1   RIAGENDR  3356 non-null   float64
#  2   RIDAGEYR  3356 non-null   float64
#  3   RIDRETH1  3356 non-null   float64
#  4   INDFMPIR  3159 non-null   float64
#  5   BMXWT     3316 non-null   float64
#  6   BMXHT     3309 non-null   float64
#  7   BMXBMI    3308 non-null   float64
#  8   BMXWAIST  3205 non-null   float64
#  9   LBXGH     3191 non-null   float64
#  10  LBXGLU    3169 non-null   float64
#  11  LBXSAL    3138 non-null   float64
#  12  LBXSATSI  3138 non-null   float64
#  13  LBXSASSI  3138 non-null   float64
#  14  LBXSAPSI  3138 non-null   float64
#  15  LBXSBU    3138 non-null   float64
#  16  LBXSGTSI  3138 non-null   float64
#  17  LBXSTB    3137 non-null   float64
#  18  LBXSUA    3138 non-null   float64
# ...

# %% [markdown]
# # 2005-2006

# %%
selected_columns = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",
    "RIAGENDR", "RIDAGEYR", "RIDRETH1",     # DEMO_D: Sex, Age, Skin Color
    "BMXBMI",                               # BMX_D
    "LBXGLU",                               # GLU_D - FastingGlucose (mg/dL)
    "LBXGH",                                # GHB_D - Glycohemoglobin (%)
    "LBXSATSI",                             # BIOPRO_D: ALT U/L
    "LBXSASSI",                             # BIOPRO_D: AST U/L
    "LBXSGTSI",                             # BIOPRO_D: GGT U/L
    "LBXSAPSI",                             # BIOPRO_D: Alkaline Phosphatase U/L
    "LBXSTB",                               # BIOPRO_D: Total Bilirubin mg/dl
    "LBXSAL",                               # BIOPRO_D: Albumin g/dl
    "LBXSCR",                               # BIOPRO_D: Creatinine mg/dl
    "LBXSBU",                               # BIOPRO_D: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # BIOPRO_D: Uric Acid mg/dl
    "LBDTCSI",                              # TCHOL_D: Total Cholesterol mmol/l
    "LBDHDDSI",                             # HDL_D: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # TRIGLY_D: LDL Cholesterol mmol/l
    "LBDTRSI",                              # TRIGLY_D: Triglycerides mmol/l    
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # CBC_D: Blood Count
    "INDFMPIR",                            # DEMO_D: PIR
    "DBQ197",                              # DBQ_D: Milk
    "LBDVIDMS",                            # VID_D: Vitamin D
]

# file paths
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2005-2006", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2005-2006", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2005-2006", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2005-2006", "Questionnaire")

# Read in the data
DEMO_D     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_D.csv"))
BMX_D      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_D.csv"))
GLU_D      = pd.read_csv(os.path.join(LAB_PATH, "GLU_D.csv"))
GHB_D     = pd.read_csv(os.path.join(LAB_PATH, "GHB_D.csv"))
BIOPRO_D  = pd.read_csv(os.path.join(LAB_PATH, "BIOPRO_D.csv"))
TCHOL_D   = pd.read_csv(os.path.join(LAB_PATH, "TCHOL_D.csv"))
HDL_D     = pd.read_csv(os.path.join(LAB_PATH, "HDL_D.csv"))
TRIGLY_D  = pd.read_csv(os.path.join(LAB_PATH, "TRIGLY_D.csv"))
CBC_D     = pd.read_csv(os.path.join(LAB_PATH, "CBC_D.csv"))
VID_D      = pd.read_csv(os.path.join(LAB_PATH, "VID_D.csv"))
Milk_D  = pd.read_csv(os.path.join( QUESTION_PATH, "DBQ_D.csv"))


# Get columns in the files
DEMO_D = DEMO_D.loc[:, DEMO_D.columns.isin(selected_columns)]
BMX_D = BMX_D.loc[:, BMX_D.columns.isin(selected_columns)]
GLU_D = GLU_D.loc[:, GLU_D.columns.isin(selected_columns)]
GHB_D = GHB_D.loc[:, GHB_D.columns.isin(selected_columns)]
BIOPRO_D = BIOPRO_D.loc[:, BIOPRO_D.columns.isin(selected_columns)]
TCHOL_D = TCHOL_D.loc[:, TCHOL_D.columns.isin(selected_columns)]
HDL_D = HDL_D.loc[:, HDL_D.columns.isin(selected_columns)]
TRIGLY_D = TRIGLY_D.loc[:, TRIGLY_D.columns.isin(selected_columns)]
CBC_D = CBC_D.loc[:, CBC_D.columns.isin(selected_columns)]
VID_D = VID_D.loc[:, VID_D.columns.isin(selected_columns)]
Milk_D = Milk_D.loc[:,Milk_D.columns.isin(selected_columns)]

# Merge the dataframes
merged_df_D = DEMO_D
merged_df_D = pd.merge(merged_df_D, BMX_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, GHB_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, GLU_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, BIOPRO_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, TCHOL_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, HDL_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, TRIGLY_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, CBC_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, Milk_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D = pd.merge(merged_df_D, VID_D, on="SEQN", how="inner", validate="one_to_one")
merged_df_D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3352 entries, 0 to 3351
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3352 non-null   float64
#  1   RIAGENDR  3352 non-null   float64
#  2   RIDAGEYR  3352 non-null   float64
#  3   RIDRETH1  3352 non-null   float64
#  4   INDFMPIR  3187 non-null   float64
#  5   BMXWT     3306 non-null   float64
#  6   BMXHT     3309 non-null   float64
#  7   BMXBMI    3302 non-null   float64
#  8   BMXWAIST  3216 non-null   float64
#  9   LBXGH     3131 non-null   float64
#  10  LBXGLU    3128 non-null   float64
#  11  LBXSAL    3095 non-null   float64
#  12  LBXSATSI  3073 non-null   float64
#  13  LBXSASSI  3073 non-null   float64
#  14  LBXSAPSI  3095 non-null   float64
#  15  LBXSBU    3095 non-null   float64
#  16  LBXSCR    3095 non-null   float64
#  17  LBXSGTSI  3094 non-null   float64
#  18  LBXSTB    3095 non-null   float64
# ...

# %% [markdown]
# # 2007-2008

# %%
selected_columns = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",
    "RIAGENDR", "RIDAGEYR", "RIDRETH1",     # DEMO_E: Sex, Age, Skin Color 
    "BMXBMI",                               # BMX_E
    "LBXGLU",                               # GLU_E - FastingGlucose (mg/dL)
    "LBXGH",                                # GHB_E - Glycohemoglobin (%)
    "LBXSATSI",                             # BIOPRO_E: ALT U/L
    "LBXSASSI",                             # BIOPRO_E: AST U/L
    "LBXSGTSI",                             # BIOPRO_E: GGT U/L
    "LBXSAPSI",                             # BIOPRO_E: Alkaline Phosphatase U/L
    "LBXSTB",                               # BIOPRO_E: Total Bilirubin mg/dl
    "LBXSAL",                               # BIOPRO_E: Albumin g/dl
    "LBXSCR",                               # BIOPRO_E: Creatinine mg/dl
    "LBXSBU",                               # BIOPRO_E: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # BIOPRO_E: Uric Acid mg/dl
    "LBDTCSI",                              # TCHOL_E: Total Cholesterol mmol/l
    "LBDHDDSI",                             # HDL_E: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # TRIGLY_E: LDL Cholesterol mmol/l
    "LBDTRSI",                              # TRIGLY_E: Triglycerides mmol/l    
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # CBC_E: Blood Count
    "INDFMPIR",                            # DEMO_E: PIR
    "DBQ197",                              # DBQ_E: Milk
    "LBXVIDMS",                            # VID_E: Vitamin D
]

# File paths
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2007-2008", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2007-2008", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2007-2008", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2007-2008", "Questionnaire")

# Read in the data
DEMO_E     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_E.csv"))
BMX_E      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_E.csv"))
GLU_E      = pd.read_csv(os.path.join(LAB_PATH, "GLU_E.csv"))
GHB_E     = pd.read_csv(os.path.join(LAB_PATH, "GHB_E.csv"))
BIOPRO_E  = pd.read_csv(os.path.join(LAB_PATH, "BIOPRO_E.csv"))
TCHOL_E   = pd.read_csv(os.path.join(LAB_PATH, "TCHOL_E.csv"))
HDL_E     = pd.read_csv(os.path.join(LAB_PATH, "HDL_E.csv"))
TRIGLY_E  = pd.read_csv(os.path.join(LAB_PATH, "TRIGLY_E.csv"))
CBC_E     = pd.read_csv(os.path.join(LAB_PATH, "CBC_E.csv"))
Milk_E      = pd.read_csv(os.path.join(QUESTION_PATH, "DBQ_E.csv"))
VID_E      = pd.read_csv(os.path.join(LAB_PATH, "VID_E.csv"))

# Get columns in the files
DEMO_E = DEMO_E.loc[:, DEMO_E.columns.isin(selected_columns)]
BMX_E = BMX_E.loc[:, BMX_E.columns.isin(selected_columns)]
GLU_E = GLU_E.loc[:, GLU_E.columns.isin(selected_columns)]
GHB_E = GHB_E.loc[:, GHB_E.columns.isin(selected_columns)]
BIOPRO_E = BIOPRO_E.loc[:, BIOPRO_E.columns.isin(selected_columns)]
TCHOL_E = TCHOL_E.loc[:, TCHOL_E.columns.isin(selected_columns)]
HDL_E = HDL_E.loc[:, HDL_E.columns.isin(selected_columns)]
TRIGLY_E = TRIGLY_E.loc[:, TRIGLY_E.columns.isin(selected_columns)]
CBC_E = CBC_E.loc[:, CBC_E.columns.isin(selected_columns)]
VID_E = VID_E.loc[:, VID_E.columns.isin(selected_columns)]
Milk_E = Milk_E.loc[:,Milk_E.columns.isin(selected_columns)]

# Merge the dataframes
merged_df_E = DEMO_E
merged_df_E = pd.merge(merged_df_E, BMX_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, GLU_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, GHB_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, BIOPRO_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, TCHOL_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, HDL_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, TRIGLY_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, CBC_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, Milk_E, on="SEQN",how="inner", validate="one_to_one")
merged_df_E = pd.merge(merged_df_E, VID_E, on="SEQN", how="inner", validate="one_to_one")
merged_df_E.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3315 entries, 0 to 3314
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3315 non-null   float64
#  1   RIAGENDR  3315 non-null   float64
#  2   RIDAGEYR  3315 non-null   float64
#  3   RIDRETH1  3315 non-null   float64
#  4   INDFMPIR  3022 non-null   float64
#  5   BMXWT     3256 non-null   float64
#  6   BMXHT     3257 non-null   float64
#  7   BMXBMI    3251 non-null   float64
#  8   BMXWAIST  3136 non-null   float64
#  9   LBXGLU    3110 non-null   float64
#  10  LBXGH     3110 non-null   float64
#  11  LBXSAL    3085 non-null   float64
#  12  LBXSATSI  3083 non-null   float64
#  13  LBXSASSI  3083 non-null   float64
#  14  LBXSAPSI  3085 non-null   float64
#  15  LBXSBU    3085 non-null   float64
#  16  LBXSCR    3084 non-null   float64
#  17  LBXSGTSI  3085 non-null   float64
#  18  LBXSTB    3084 non-null   float64
# ...

# %% [markdown]
# # 2009-2010

# %%
selected_columns = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",
    "RIAGENDR", "RIDAGEYR", "RIDRETH1",     # DEMO_F: Sex, Age, Skin Color 
    "BMXBMI",                               # BMX_F
    "LBXGLU",                               # GLU_F - FastingGlucose (mg/dL)
    "LBXGH",                                # GHB_F - Glycohemoglobin (%)
    "LBXSATSI",                             # BIOPRO_F: ALT U/L
    "LBXSASSI",                             # BIOPRO_F: AST U/L
    "LBXSGTSI",                             # BIOPRO_F: GGT U/L
    "LBXSAPSI",                             # BIOPRO_F: Alkaline Phosphatase U/L
    "LBXSTB",                               # BIOPRO_F: Total Bilirubin mg/dl
    "LBXSAL",                               # BIOPRO_F: Albumin g/dl
    "LBXSCR",                               # BIOPRO_F: Creatinine mg/dl
    "LBXSBU",                               # BIOPRO_F: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # BIOPRO_F: Uric Acid mg/dl
    "LBDTCSI",                              # TCHOL_F: Total Cholesterol mmol/l
    "LBDHDDSI",                             # HDL_F: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # TRIGLY_F: LDL Cholesterol mmol/l
    "LBDTRSI",                              # TRIGLY_F: Triglycerides mmol/l    
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # CBC_F: Blood Count
    "INDFMPIR",                            # DEMO_F: PIR
    "DBQ197",                              # DBQ_F: Milk
    "LBXVIDMS",                            # VID_F: Vitamin D 
]

# File paths
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2009-2010", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2009-2010", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2009-2010", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2009-2010", "Questionnaire")

# Read in the data
DEMO_F     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_F.csv"))
BMX_F      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_F.csv"))
GLU_F      = pd.read_csv(os.path.join(LAB_PATH, "GLU_F.csv"))
GHB_F     = pd.read_csv(os.path.join(LAB_PATH, "GHB_F.csv"))
BIOPRO_F  = pd.read_csv(os.path.join(LAB_PATH, "BIOPRO_F.csv"))
TCHOL_F   = pd.read_csv(os.path.join(LAB_PATH, "TCHOL_F.csv"))
HDL_F     = pd.read_csv(os.path.join(LAB_PATH, "HDL_F.csv"))
TRIGLY_F  = pd.read_csv(os.path.join(LAB_PATH, "TRIGLY_F.csv"))
CBC_F     = pd.read_csv(os.path.join(LAB_PATH, "CBC_F.csv"))
VID_F      = pd.read_csv(os.path.join(LAB_PATH, "VID_F.csv"))
Milk_F = pd.read_csv(os.path.join(QUESTION_PATH,'DBQ_F.csv'))

# Get columns in the files
DEMO_F = DEMO_F.loc[:, DEMO_F.columns.isin(selected_columns)]
BMX_F = BMX_F.loc[:, BMX_F.columns.isin(selected_columns)]
GLU_F = GLU_F.loc[:, GLU_F.columns.isin(selected_columns)]
GHB_F = GHB_F.loc[:, GHB_F.columns.isin(selected_columns)]
BIOPRO_F = BIOPRO_F.loc[:, BIOPRO_F.columns.isin(selected_columns)]
TCHOL_F = TCHOL_F.loc[:, TCHOL_F.columns.isin(selected_columns)]
HDL_F = HDL_F.loc[:, HDL_F.columns.isin(selected_columns)]
TRIGLY_F = TRIGLY_F.loc[:, TRIGLY_F.columns.isin(selected_columns)]
CBC_F = CBC_F.loc[:, CBC_F.columns.isin(selected_columns)]
VID_F = VID_F.loc[:, VID_F.columns.isin(selected_columns)]
Milk_F = Milk_F.loc[:,Milk_F.columns.isin(selected_columns)]

# Merge the dataframes
merged_df_F = pd.merge(DEMO_F, BMX_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, GLU_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, GHB_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, BIOPRO_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, TCHOL_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, HDL_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, TRIGLY_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, CBC_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, Milk_F, on='SEQN', how='inner', validate="one_to_one")
merged_df_F = pd.merge(merged_df_F, VID_F, on="SEQN", how="inner", validate="one_to_one")
merged_df_F.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3581 entries, 0 to 3580
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3581 non-null   float64
#  1   RIAGENDR  3581 non-null   float64
#  2   RIDAGEYR  3581 non-null   float64
#  3   RIDRETH1  3581 non-null   float64
#  4   INDFMPIR  3212 non-null   float64
#  5   BMXWT     3545 non-null   float64
#  6   BMXHT     3546 non-null   float64
#  7   BMXBMI    3541 non-null   float64
#  8   BMXWAIST  3417 non-null   float64
#  9   LBXGLU    3386 non-null   float64
#  10  LBXGH     3385 non-null   float64
#  11  LBXSAL    3350 non-null   float64
#  12  LBXSATSI  3349 non-null   float64
#  13  LBXSASSI  3349 non-null   float64
#  14  LBXSAPSI  3350 non-null   float64
#  15  LBXSBU    3350 non-null   float64
#  16  LBXSCR    3350 non-null   float64
#  17  LBXSGTSI  3349 non-null   float64
#  18  LBXSTB    3347 non-null   float64
# ...

# %% [markdown]
# # 2011-2012

# %%
selected_columns = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",
    "RIAGENDR", "RIDAGEYR", "RIDRETH1",     # DEMO_G: Sex, Age, Skin Color 
    "BMXBMI",                               # BMX_G
    "LBXGLU",                               # GLU_G - FastingGlucose (mg/dL)
    "LBXGH",                                # GHB_G - Glycohemoglobin (%)
    "LBXSATSI",                             # BIOPRO_G: ALT U/L
    "LBXSASSI",                             # BIOPRO_G: AST U/L
    "LBXSGTSI",                             # BIOPRO_G: GGT U/L
    "LBXSAPSI",                             # BIOPRO_G: Alkaline Phosphatase U/L
    "LBXSTB",                               # BIOPRO_G: Total Bilirubin mg/dl
    "LBXSAL",                               # BIOPRO_G: Albumin g/dl
    "LBXSCR",                               # BIOPRO_G: Creatinine mg/dl
    "LBXSBU",                               # BIOPRO_G: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # BIOPRO_G: Uric Acid mg/dl
    "LBDTCSI",                              # TCHOL_G: Total Cholesterol mmol/l
    "LBDHDDSI",                             # HDL_G: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # TRIGLY_G: LDL Cholesterol mmol/l
    "LBDTRSI",                              # TRIGLY_G: Triglycerides mmol/l    
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # CBC_G: Blood Count
    "INDFMPIR",                            # DEMO_G: PIR
    "DBQ197",                              # DBQ_G: Milk
    "LBXVIDMS",                            # VID_G: Vitamin D 
]

#file paths
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2011-2012", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2011-2012", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2011-2012", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2011-2012", "Questionnaire")

# Read in the data
DEMO_G     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_G.csv"))
BMX_G      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_G.csv"))
GLU_G      = pd.read_csv(os.path.join(LAB_PATH, "GLU_G.csv"))
GHB_G     = pd.read_csv(os.path.join(LAB_PATH, "GHB_G.csv"))
BIOPRO_G  = pd.read_csv(os.path.join(LAB_PATH, "BIOPRO_G.csv"))
TCHOL_G   = pd.read_csv(os.path.join(LAB_PATH, "TCHOL_G.csv"))
HDL_G     = pd.read_csv(os.path.join(LAB_PATH, "HDL_G.csv"))
TRIGLY_G  = pd.read_csv(os.path.join(LAB_PATH, "TRIGLY_G.csv"))
CBC_G     = pd.read_csv(os.path.join(LAB_PATH, "CBC_G.csv"))
VID_G   = pd.read_csv(os.path.join(LAB_PATH, "VID_G.csv"))
Milk_G  = pd.read_csv(os.path.join(QUESTION_PATH,"DBQ_G.csv"))

# Get columns in the files
DEMO_G = DEMO_G.loc[:, DEMO_G.columns.isin(selected_columns)]
BMX_G = BMX_G.loc[:, BMX_G.columns.isin(selected_columns)]
GLU_G = GLU_G.loc[:, GLU_G.columns.isin(selected_columns)]
GHB_G = GHB_G.loc[:, GHB_G.columns.isin(selected_columns)]
BIOPRO_G = BIOPRO_G.loc[:, BIOPRO_G.columns.isin(selected_columns)]
TCHOL_G = TCHOL_G.loc[:, TCHOL_G.columns.isin(selected_columns)]
HDL_G = HDL_G.loc[:, HDL_G.columns.isin(selected_columns)]
TRIGLY_G = TRIGLY_G.loc[:, TRIGLY_G.columns.isin(selected_columns)]
CBC_G = CBC_G.loc[:, CBC_G.columns.isin(selected_columns)]
VID_G = VID_G.loc[:, VID_G.columns.isin(selected_columns)]
Milk_G = Milk_G.loc[:,Milk_G.columns.isin(selected_columns)]

# Merge the dataframes
merged_df_G = pd.merge(DEMO_G, BMX_G, on="SEQN", how="inner", validate="one_to_one")
merged_df_G = pd.merge(merged_df_G, GLU_G, on="SEQN", how="inner", validate="one_to_one")
merged_df_G = pd.merge(merged_df_G, GHB_G, on="SEQN", how="inner", validate="one_to_one")
merged_df_G = pd.merge(merged_df_G, BIOPRO_G, on="SEQN", how="inner", validate="one_to_one")
merged_df_G = pd.merge(merged_df_G, TCHOL_G, on="SEQN", how="inner", validate="one_to_one")
merged_df_G = pd.merge(merged_df_G, HDL_G, on="SEQN", how="inner", validate="one_to_one")
merged_df_G = pd.merge(merged_df_G, TRIGLY_G, on="SEQN", how="inner", validate="one_to_one")
merged_df_G = pd.merge(merged_df_G, CBC_G, on="SEQN", how="inner", validate="one_to_one")
merged_df_G = pd.merge(merged_df_G,Milk_G,on='SEQN',how='inner', validate="one_to_one")
merged_df_G = pd.merge(merged_df_G, VID_G, on="SEQN", how="inner", validate="one_to_one") 

merged_df_G.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3239 non-null   float64
#  1   RIAGENDR  3239 non-null   float64
#  2   RIDAGEYR  3239 non-null   float64
#  3   RIDRETH1  3239 non-null   float64
#  4   INDFMPIR  2961 non-null   float64
#  5   BMXWT     3193 non-null   float64
#  6   BMXHT     3197 non-null   float64
#  7   BMXBMI    3190 non-null   float64
#  8   BMXWAIST  3073 non-null   float64
#  9   LBXGLU    3033 non-null   float64
#  10  LBXGH     3059 non-null   float64
#  11  LBXSAL    2976 non-null   float64
#  12  LBXSATSI  2975 non-null   float64
#  13  LBXSASSI  2972 non-null   float64
#  14  LBXSAPSI  2975 non-null   float64
#  15  LBXSBU    2976 non-null   float64
#  16  LBXSCR    2976 non-null   float64
#  17  LBXSGTSI  2975 non-null   float64
#  18  LBXSTB    2972 non-null   float64
# ...

# %% [markdown]
# # 2013-2014

# %%
selected_columns = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",
    "RIAGENDR", "RIDAGEYR", "RIDRETH1",     # DEMO_H: Sex, Age, Skin Color 
    "BMXBMI",                               # BMX_H
    "LBXGLU",                               # GLU_H - FastingGlucose (mg/dL)
    "LBXGH",                                # GHB_H - Glycohemoglobin (%)
    "LBXSATSI",                             # BIOPRO_H: ALT U/L
    "LBXSASSI",                             # BIOPRO_H: AST U/L
    "LBXSGTSI",                             # BIOPRO_H: GGT U/L
    "LBXSAPSI",                             # BIOPRO_H: Alkaline Phosphatase U/L
    "LBXSTB",                               # BIOPRO_H: Total Bilirubin mg/dl
    "LBXSAL",                               # BIOPRO_H: Albumin g/dl
    "LBXSCR",                               # BIOPRO_H: Creatinine mg/dl
    "LBXSBU",                               # BIOPRO_H: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # BIOPRO_H: Uric Acid mg/dl
    "LBDTCSI",                              # TCHOL_H: Total Cholesterol mmol/l
    "LBDHDDSI",                             # HDL_H: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # TRIGLY_H: LDL Cholesterol mmol/l
    "LBDTRSI",                              # TRIGLY_H: Triglycerides mmol/l    
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # CBC_H: Blood Count
    "INDFMPIR",                            # DEMO_H: PIR
    "DBQ197",                              # DBQ_H: Milk
    "LBXVIDMS",                            # VID_H: Vitamin D 
]

#file paths
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2013-2014", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2013-2014", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2013-2014", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2013-2014", "Questionnaire")

# Read in the data
DEMO_H     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_H.csv"))
BMX_H      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_H.csv"))
GLU_H      = pd.read_csv(os.path.join(LAB_PATH, "GLU_H.csv"))
GHB_H     = pd.read_csv(os.path.join(LAB_PATH, "GHB_H.csv"))
BIOPRO_H  = pd.read_csv(os.path.join(LAB_PATH, "BIOPRO_H.csv"))
TCHOL_H   = pd.read_csv(os.path.join(LAB_PATH, "TCHOL_H.csv"))
HDL_H     = pd.read_csv(os.path.join(LAB_PATH, "HDL_H.csv"))
TRIGLY_H  = pd.read_csv(os.path.join(LAB_PATH, "TRIGLY_H.csv"))
CBC_H     = pd.read_csv(os.path.join(LAB_PATH, "CBC_H.csv"))
VID_H      = pd.read_csv(os.path.join(LAB_PATH, "VID_H.csv"))
Milk_H = pd.read_csv(os.path.join(QUESTION_PATH,"DBQ_H.csv"))

# Get columns in the files
DEMO_H = DEMO_H.loc[:, DEMO_H.columns.isin(selected_columns)]
BMX_H = BMX_H.loc[:, BMX_H.columns.isin(selected_columns)]
GLU_H = GLU_H.loc[:, GLU_H.columns.isin(selected_columns)]
GHB_H = GHB_H.loc[:, GHB_H.columns.isin(selected_columns)]
BIOPRO_H = BIOPRO_H.loc[:, BIOPRO_H.columns.isin(selected_columns)]
TCHOL_H = TCHOL_H.loc[:, TCHOL_H.columns.isin(selected_columns)]
HDL_H = HDL_H.loc[:, HDL_H.columns.isin(selected_columns)]
TRIGLY_H = TRIGLY_H.loc[:, TRIGLY_H.columns.isin(selected_columns)]
CBC_H = CBC_H.loc[:, CBC_H.columns.isin(selected_columns)]
VID_H = VID_H.loc[:, VID_H.columns.isin(selected_columns)]
Milk_H = Milk_H.loc[:, Milk_H.columns.isin(selected_columns)]

# Merge the dataframes
merged_df_H = pd.merge(DEMO_H, BMX_H, on="SEQN", how="inner", validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, GLU_H, on="SEQN", how="inner", validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, GHB_H, on="SEQN", how="inner", validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, BIOPRO_H, on="SEQN", how="inner", validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, TCHOL_H, on="SEQN", how="inner", validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, HDL_H, on="SEQN", how="inner", validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, TRIGLY_H, on="SEQN", how="inner", validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, CBC_H, on="SEQN", how="inner", validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, Milk_H,on='SEQN',how='inner', validate="one_to_one")
merged_df_H = pd.merge(merged_df_H, VID_H, on="SEQN", how="inner", validate="one_to_one")

merged_df_H.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3329 entries, 0 to 3328
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3329 non-null   float64
#  1   RIAGENDR  3329 non-null   float64
#  2   RIDAGEYR  3329 non-null   float64
#  3   RIDRETH1  3329 non-null   float64
#  4   INDFMPIR  3085 non-null   float64
#  5   BMXWT     3299 non-null   float64
#  6   BMXHT     3295 non-null   float64
#  7   BMXBMI    3291 non-null   float64
#  8   BMXWAIST  3160 non-null   float64
#  9   LBXGLU    3172 non-null   float64
#  10  LBXGH     3184 non-null   float64
#  11  LBXSAL    3135 non-null   float64
#  12  LBXSAPSI  3134 non-null   float64
#  13  LBXSASSI  3133 non-null   float64
#  14  LBXSATSI  3133 non-null   float64
#  15  LBXSBU    3135 non-null   float64
#  16  LBXSCR    3135 non-null   float64
#  17  LBXSGTSI  3134 non-null   float64
#  18  LBXSTB    3131 non-null   float64
# ...

# %% [markdown]
# # 2015-2016

# %%
selected_columns = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",
    "RIAGENDR", "RIDAGEYR", "RIDRETH1",     # DEMO_I: Sex, Age, Skin Color 
    "BMXBMI",                               # BMX_I
    "LBXGLU",                               # GLU_I - FastingGlucose (mg/dL)
    "LBXGH",                                # GHB_I - Glycohemoglobin (%)
    "LBXSATSI",                             # BIOPRO_I: ALT U/L
    "LBXSASSI",                             # BIOPRO_I: AST U/L
    "LBXSGTSI",                             # BIOPRO_I: GGT U/L
    "LBXSAPSI",                             # BIOPRO_I: Alkaline Phosphatase U/L
    "LBXSTB",                               # BIOPRO_I: Total Bilirubin mg/dl
    "LBXSAL",                               # BIOPRO_I: Albumin g/dl
    "LBXSCR",                               # BIOPRO_I: Creatinine mg/dl
    "LBXSBU",                               # BIOPRO_I: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # BIOPRO_I: Uric Acid mg/dl
    "LBDTCSI",                              # TCHOL_I: Total Cholesterol mmol/l
    "LBDHDDSI",                             # HDL_I: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # TRIGLY_I: LDL Cholesterol mmol/l
    "LBDTRSI",                              # TRIGLY_I: Triglycerides mmol/l    
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # CBC_I: Blood Count
    "INDFMPIR",                            # DEMO_I: PIR
    "DBQ197",                              # DBQ_I: Milk
    "LBXVIDMS",                            # VID_I: Vitamin D 
]

# File paths
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2015-2016", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2015-2016", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2015-2016", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2015-2016", "Questionnaire")

# Read in the data
DEMO_I     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_I.csv"))
BMX_I      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_I.csv"))
GLU_I      = pd.read_csv(os.path.join(LAB_PATH, "GLU_I.csv"))
GHB_I     = pd.read_csv(os.path.join(LAB_PATH, "GHB_I.csv"))
BIOPRO_I  = pd.read_csv(os.path.join(LAB_PATH, "BIOPRO_I.csv"))
TCHOL_I   = pd.read_csv(os.path.join(LAB_PATH, "TCHOL_I.csv"))
HDL_I     = pd.read_csv(os.path.join(LAB_PATH, "HDL_I.csv"))
TRIGLY_I  = pd.read_csv(os.path.join(LAB_PATH, "TRIGLY_I.csv"))
CBC_I     = pd.read_csv(os.path.join(LAB_PATH, "CBC_I.csv"))
VID_I      = pd.read_csv(os.path.join(LAB_PATH, "VID_I.csv"))
Milk_I = pd.read_csv(os.path.join(QUESTION_PATH,"DBQ_I.csv"))

# Get columns in the files
DEMO_I = DEMO_I.loc[:, DEMO_I.columns.isin(selected_columns)]
BMX_I = BMX_I.loc[:, BMX_I.columns.isin(selected_columns)]
GLU_I = GLU_I.loc[:, GLU_I.columns.isin(selected_columns)]
GHB_I = GHB_I.loc[:, GHB_I.columns.isin(selected_columns)]
BIOPRO_I = BIOPRO_I.loc[:, BIOPRO_I.columns.isin(selected_columns)]
TCHOL_I = TCHOL_I.loc[:, TCHOL_I.columns.isin(selected_columns)]
HDL_I = HDL_I.loc[:, HDL_I.columns.isin(selected_columns)]
TRIGLY_I = TRIGLY_I.loc[:, TRIGLY_I.columns.isin(selected_columns)]
CBC_I = CBC_I.loc[:, CBC_I.columns.isin(selected_columns)]
VID_I = VID_I.loc[:, VID_I.columns.isin(selected_columns)]
Milk_I = Milk_I.loc[:,Milk_I.columns.isin(selected_columns)]

# Merge the dataframes
merged_df_I = pd.merge(DEMO_I, BMX_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, GLU_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, GHB_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, BIOPRO_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, TCHOL_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, HDL_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, TRIGLY_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, CBC_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, Milk_I, on='SEQN', how='inner', validate="one_to_one")
merged_df_I = pd.merge(merged_df_I, VID_I, on="SEQN", how="inner", validate="one_to_one")
merged_df_I.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3191 entries, 0 to 3190
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3191 non-null   float64
#  1   RIAGENDR  3191 non-null   float64
#  2   RIDAGEYR  3191 non-null   float64
#  3   RIDRETH1  3191 non-null   float64
#  4   INDFMPIR  2860 non-null   float64
#  5   BMXWT     3157 non-null   float64
#  6   BMXHT     3160 non-null   float64
#  7   BMXBMI    3154 non-null   float64
#  8   BMXWAIST  3009 non-null   float64
#  9   LBXGLU    2972 non-null   float64
#  10  LBXGH     2981 non-null   float64
#  11  LBXSAL    2949 non-null   float64
#  12  LBXSAPSI  2948 non-null   float64
#  13  LBXSASSI  2949 non-null   float64
#  14  LBXSATSI  2949 non-null   float64
#  15  LBXSBU    2948 non-null   float64
#  16  LBXSCR    2948 non-null   float64
#  17  LBXSGTSI  2949 non-null   float64
#  18  LBXSTB    2948 non-null   float64
# ...

# %% [markdown]
# # 2017-2018

# %%
selected_columns = [
    "SEQN",
    "BMXWT",
    "BMXHT",
    "BMXWAIST",
    "RIAGENDR", "RIDAGEYR", "RIDRETH1",     # DEMO_J: Sex, Age, Skin Color 
    "BMXBMI",                               # BMX_J
    "LBXGLU",                               # GLU_J - FastingGlucose (mg/dL)
    "LBXGH",                                # GHB_J - Glycohemoglobin (%)
    "LBXSATSI",                             # BIOPRO_J: ALT U/L
    "LBXSASSI",                             # BIOPRO_J: AST U/L
    "LBXSGTSI",                             # BIOPRO_J: GGT U/L
    "LBXSAPSI",                             # BIOPRO_J: Alkaline Phosphatase U/L
    "LBXSTB",                               # BIOPRO_J: Total Bilirubin mg/dl
    "LBXSAL",                               # BIOPRO_J: Albumin g/dl
    "LBXSCR",                               # BIOPRO_J: Creatinine mg/dl
    "LBXSBU",                               # BIOPRO_J: Blood Urea Nitrogen mg/dl
    "LBXSUA",                               # BIOPRO_J: Uric Acid mg/dl
    "LBDTCSI",                              # TCHOL_J: Total Cholesterol mmol/l
    "LBDHDDSI",                             # HDL_J: HDL Cholesterol mmol/l
    "LBDLDLSI",                             # TRIGLY_J: LDL Cholesterol mmol/l
    "LBDTRSI",                              # TRIGLY_J: Triglycerides mmol/l    
    "LBXHGB", "LBXHCT", "LBXMCVSI", "LBXMC", "LBXRDW", "LBXPLTSI", "LBXMPSI",  # CBC_J: Blood Count
    "INDFMPIR",                            # DEMO_J: PIR
    "DBQ197",                              # DBQ_J: Milk
    "LBXVIDMS",                            # VID_J: Vitamin D 
]

#file paths
DEMO_PATH = os.path.join(DATA_DIRECTORY, "2017-2018", "Demographics")
LAB_PATH = os.path.join(DATA_DIRECTORY, "2017-2018", "Laboratory")
EXAM_PATH = os.path.join(DATA_DIRECTORY, "2017-2018", "Examination")
QUESTION_PATH = os.path.join(DATA_DIRECTORY, "2017-2018", "Questionnaire")

# Read in the data
DEMO_J     = pd.read_csv(os.path.join(DEMO_PATH, "DEMO_J.csv"))
BMX_J      = pd.read_csv(os.path.join(EXAM_PATH, "BMX_J.csv"))
GLU_J      = pd.read_csv(os.path.join(LAB_PATH, "GLU_J.csv"))
GHB_J     = pd.read_csv(os.path.join(LAB_PATH, "GHB_J.csv"))
BIOPRO_J  = pd.read_csv(os.path.join(LAB_PATH, "BIOPRO_J.csv"))
TCHOL_J   = pd.read_csv(os.path.join(LAB_PATH, "TCHOL_J.csv"))
HDL_J     = pd.read_csv(os.path.join(LAB_PATH, "HDL_J.csv"))
TRIGLY_J  = pd.read_csv(os.path.join(LAB_PATH, "TRIGLY_J.csv"))
CBC_J     = pd.read_csv(os.path.join(LAB_PATH, "CBC_J.csv"))
VID_J      = pd.read_csv(os.path.join(LAB_PATH, "VID_J.csv"))
Milk_J = pd.read_csv(os.path.join(QUESTION_PATH,'DBQ_J.csv'))

# Get columns in the files
DEMO_J = DEMO_J.loc[:, DEMO_J.columns.isin(selected_columns)]
BMX_J = BMX_J.loc[:, BMX_J.columns.isin(selected_columns)]
GLU_J = GLU_J.loc[:, GLU_J.columns.isin(selected_columns)]
GHB_J = GHB_J.loc[:, GHB_J.columns.isin(selected_columns)]
BIOPRO_J = BIOPRO_J.loc[:, BIOPRO_J.columns.isin(selected_columns)]
TCHOL_J = TCHOL_J.loc[:, TCHOL_J.columns.isin(selected_columns)]
HDL_J = HDL_J.loc[:, HDL_J.columns.isin(selected_columns)]
TRIGLY_J = TRIGLY_J.loc[:, TRIGLY_J.columns.isin(selected_columns)]
CBC_J = CBC_J.loc[:, CBC_J.columns.isin(selected_columns)]
VID_J = VID_J.loc[:, VID_J.columns.isin(selected_columns)]
Milk_J = Milk_J.loc[:,Milk_J.columns.isin(selected_columns)]

# Merge the dataframes
merged_df_J = pd.merge(DEMO_J, BMX_J, on="SEQN", how="inner", validate="one_to_one")
merged_df_J = pd.merge(merged_df_J, GLU_J, on="SEQN", how="inner", validate="one_to_one") 
merged_df_J = pd.merge(merged_df_J, GHB_J, on="SEQN", how="inner", validate="one_to_one")
merged_df_J = pd.merge(merged_df_J, BIOPRO_J, on="SEQN", how="inner", validate="one_to_one")
merged_df_J = pd.merge(merged_df_J, TCHOL_J, on="SEQN", how="inner", validate="one_to_one")
merged_df_J = pd.merge(merged_df_J, HDL_J, on="SEQN", how="inner", validate="one_to_one")
merged_df_J = pd.merge(merged_df_J, TRIGLY_J, on="SEQN", how="inner", validate="one_to_one")
merged_df_J = pd.merge(merged_df_J, CBC_J, on="SEQN", how="inner", validate="one_to_one")
merged_df_J = pd.merge(merged_df_J,Milk_J,on='SEQN',how='inner', validate="one_to_one") 
merged_df_J = pd.merge(merged_df_J, VID_J, on="SEQN", how="inner", validate="one_to_one")

merged_df_J.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3036 entries, 0 to 3035
# Data columns (total 33 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      3036 non-null   float64
#  1   RIAGENDR  3036 non-null   float64
#  2   RIDAGEYR  3036 non-null   float64
#  3   RIDRETH1  3036 non-null   float64
#  4   INDFMPIR  2629 non-null   float64
#  5   BMXWT     2984 non-null   float64
#  6   BMXHT     2985 non-null   float64
#  7   BMXBMI    2981 non-null   float64
#  8   BMXWAIST  2869 non-null   float64
#  9   LBXGLU    2891 non-null   float64
#  10  LBXGH     2899 non-null   float64
#  11  LBXSATSI  2831 non-null   float64
#  12  LBXSAL    2833 non-null   float64
#  13  LBXSAPSI  2831 non-null   float64
#  14  LBXSASSI  2823 non-null   float64
#  15  LBXSBU    2830 non-null   float64
#  16  LBXSCR    2832 non-null   float64
#  17  LBXSGTSI  2831 non-null   float64
#  18  LBXSTB    2832 non-null   float64
# ...

# %% [markdown]
# # 2.INSTRUCTION LIST: RAW->TIDY

# %% [markdown]
# ## 2.1 Rename column

# %%
#rename for 2001->2004
def rename_nhanes_columns(df):
    rename_map = {
        "SEQN": "SEQN",
        "RIAGENDR":"Gender",
        "RIDAGEYR": "Age",
        "RIDRETH1": "Race",
        "BMXWT": "Weight",
        "BMXHT": "Height",
        "BMXBMI": "BMI",
        "BMXWAIST": "WaistCircumference",
        "LBXGLU": "FastingGlucose",
        "LBXGH":"Hba1c", 
        "LBXSATSI":"ALT",
        "LBXSASSI":"AST",
        "LBXSGTSI":"GGT",
        "LBDSAPSI":"AlkalinePhosphotase",
        "LBXSAPSI":"AlkalinePhosphotase",
        "LBXSTB":"TotalBilirubin",
        "LBDSTB": "TotalBilirubin",
        "LBXSAL":"Albumin",
        "LBDSCR":"Creatinine",
        "LBXSCR":"Creatinine",
        "LBXSBU":"BUN",
        "LBXSUA": "UricAcid",
        "LBDTCSI":"TotalCholesterol",
        "LBDHDDSI": "HDLCholesterol",
        "LBDHDLSI": "HDLCholesterol",
        "LBDLDLSI": "LDLCholesterol",
        "LBDTRSI": "Triglycerides",
        "LBXHGB": "Hemoglobin",
        "LBXHCT": "Hematocrit",
        "LBXMCVSI": "MeanCellVolumn",
        "LBXMC": "MeanCellHemoglobin",
        "LBXRDW": "RedCellDistributionWidth",
        "LBXPLTSI": "PlateletCount",
        "LBXMPSI": "MeanPlateletVolume",
        "LBXTSH": "HBsAg",
        "DBD196":"milk_consumption",
        "DBD197":"milk_consumption",
        "DBQ197":"milk_consumption",
        "INDFMPIR":"PIR",
        "SMD460":"SmokeFam",
        "LBDVIDMS": "VitaminD",
        "LBXVIDMS": "VitaminD",

    }
    return df.rename(columns=rename_map)

# %%
merged_df_B = rename_nhanes_columns(merged_df_B)
merged_df_C = rename_nhanes_columns(merged_df_C)
merged_df_D = rename_nhanes_columns(merged_df_D)
merged_df_E = rename_nhanes_columns(merged_df_E)
merged_df_F = rename_nhanes_columns(merged_df_F)
merged_df_G = rename_nhanes_columns(merged_df_G)
merged_df_H = rename_nhanes_columns(merged_df_H)
merged_df_I = rename_nhanes_columns(merged_df_I)
merged_df_J = rename_nhanes_columns(merged_df_J)

# %%
merged_df_B['YearID'] = '2001-2002'
merged_df_C['YearID'] = '2003-2004'
merged_df_D['YearID'] = '2005-2006'
merged_df_E['YearID'] = '2007-2008'
merged_df_F['YearID'] = '2009-2010'
merged_df_G['YearID'] = '2011-2012'
merged_df_H['YearID'] = '2013-2014'
merged_df_I['YearID'] = '2015-2016'
merged_df_J['YearID'] = '2017-2018'

# %%
# Concatenate all merged dataframes into one
merged_df_all = pd.concat([
    merged_df_B,
    merged_df_C,
    merged_df_D,
    merged_df_E,
    merged_df_F,
    merged_df_G,
    merged_df_H,
    merged_df_I,
    merged_df_J
], ignore_index=True)

# %%
merged_df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30065 entries, 0 to 30064
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SEQN                      30065 non-null  float64
#  1   Gender                    30065 non-null  float64
#  2   Age                       30065 non-null  float64
#  3   Race                      30065 non-null  float64
#  4   PIR                       27524 non-null  float64
#  5   Weight                    29603 non-null  float64
#  6   Height                    29635 non-null  float64
#  7   BMI                       29511 non-null  float64
#  8   WaistCircumference        28600 non-null  float64
#  9   Hba1c                     28397 non-null  float64
#  10  FastingGlucose            28302 non-null  float64
#  11  Albumin                   27953 non-null  float64
#  12  ALT                       27923 non-null  float64
# ...

# %%
merged_df_all.to_csv(r'C:\mydata\G8Vitamin\data\duy\raw_final.csv', index=False)
